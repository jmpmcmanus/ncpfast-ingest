# %%
import sqlite3
import pandas as pd
import numpy as np
from toolz import frequencies, valfilter

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
def select_geolocation(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("SELECT * FROM geolocation ORDER BY epa_srcid")

    rows = cur.fetchall()
    
    df = pd.DataFrame(columns = ['EPA_srcID','PWS_ID','lon','lat','Own_Loc_Co','Src_Type','Src_Name',
                                 'Src_Avl','Src_Locati','Locn_Dtrm','WELL_I_RAT','WSWCLASS','RWQ_RATE',
                                 'INTK_LOC','Yield_Gpm','DEG_CONF','Depth','RECHRATE','AQRATE','Pws_Type',
                                 'Rtl_Nbr_Cn','Rtl_Pop','System_Nam','Descript_1','Loc_Addr1','Loc_City',
                                 'Loc_State','Loc_Zip1','County','Owner','Ownr_Addr1','Ownr_Addr2','Ownr_City',
                                 'Ownr_Zip1','Ownr_Zip2','Prdtn_Capt','Prdtn_Ca_1','Prdtn_Ca_2','Prdtn_Ca_3',
                                 'PWSTypeDes','PWSTypeNam','Begin_Date','Sys_County','DEQ_Reg_Na','Ownr_State']) 
    for row in rows:
        df = df.append({'EPA_srcID': row[0],'PWS_ID': row[1],'lon': row[2],'lat': row[3],'Own_Loc_Co': row[4],
                   'Src_Type': row[5],'Src_Name': row[6],'Src_Avl': row[7],'Src_Locati': ", ".join(str(row[8]).splitlines()),
                   'Locn_Dtrm': row[9],'WELL_I_RAT': row[10],'WSWCLASS': row[11],'RWQ_RATE': row[12],
                   'INTK_LOC': row[13],'Yield_Gpm': row[14],'DEG_CONF': row[15],'Depth': row[16],
                   'RECHRATE': row[17],'AQRATE': row[18],'Pws_Type': row[19],'Rtl_Nbr_Cn': row[20],
                   'Rtl_Pop': row[21],'System_Nam': row[22],'Descript_1': row[23],'Loc_Addr1': row[24],
                   'Loc_City': row[25],'Loc_State': row[26],'Loc_Zip1': row[27],'County': row[28],
                   'Owner': row[29],'Ownr_Addr1': row[30],'Ownr_Addr2': row[31],'Ownr_City': row[32],
                   'Ownr_Zip1': row[33],'Ownr_Zip2': row[34],'Prdtn_Capt': row[35],'Prdtn_Ca_1': row[36],
                   'Prdtn_Ca_2': row[37],'Prdtn_Ca_3': row[38],'PWSTypeDes': row[39],'PWSTypeNam': row[40],
                   'Begin_Date': row[41],'Sys_County': row[42],'DEQ_Reg_Na': row[43],'Ownr_State': row[44]}, 
                  ignore_index = True)

    return df

# %%
db_file = '../RoundOneDB/RoundOneDB_final.db'
conn = create_connection(db_file)
df = select_geolocation(conn)
df.head()
# Out:
#   EPA_srcID  PWS_ID        lon        lat Own_Loc_Co Src_Type  Src_Name  \
# 0     11245  100103 -82.207111  35.763762        W01        G   WELL #1
# 1     11246  100103 -82.207991  35.764855        W03        G   WELL #3
# 2     11247  100103 -82.204079  35.767117        W3A        G  WELL #3A
# 3     11248  100103 -82.194494  35.767939        W04        G   WELL #4
# 4     11251  100105 -82.349286  35.867846        W01        G   WELL #1
#
#   Src_Avl                                 Src_Locati Locn_Dtrm  ...  \
# 0       P   SWEETWATER RD- ON RIGHT JUST PAST BRIDGE         E  ...
# 1       P                      SWEETWATER RD ON LEFT         E  ...
# 2       P  RIGHT SIDE OF S TOE RIVER RD GOING TO S\D         E  ...
# 3       P             END OF FOREST SERVICE RD ON RT         E  ...
# 4       P                              MTN AIR DRIVE         E  ...
#
#   Prdtn_Capt Prdtn_Ca_1 Prdtn_Ca_2 Prdtn_Ca_3  \
# 0    57572.0   162000.0        0.0        0.0
# 1    57572.0   162000.0        0.0        0.0
# 2    57572.0   162000.0        0.0        0.0
# 3    57572.0   162000.0        0.0        0.0
# 4    30000.0    25180.0        0.0    45000.0
#
#                                           PWSTypeDes PWSTypeNam  Begin_Date  \
# 0  Serves 15+ connections or regularly serves 25+...  Community  1977-01-01
# 1  Serves 15+ connections or regularly serves 25+...  Community  1986-07-01
# 2  Serves 15+ connections or regularly serves 25+...  Community  1994-10-01
# 3  Serves 15+ connections or regularly serves 25+...  Community  1994-10-01
# 4  Serves 15+ connections or regularly serves 25+...  Community  1995-04-01
#
#    Sys_County                 DEQ_Reg_Na Ownr_State
# 0      YANCEY  ASHEVILLE REGIONAL OFFICE         NC
# 1      YANCEY  ASHEVILLE REGIONAL OFFICE         NC
# 2      YANCEY  ASHEVILLE REGIONAL OFFICE         NC
# 3      YANCEY  ASHEVILLE REGIONAL OFFICE         NC
# 4      YANCEY  ASHEVILLE REGIONAL OFFICE         NC
#
# [5 rows x 45 columns]

# %%
outfile = '../RoundOneDB/RoundOneDB-Geolocation.csv'
df.to_csv(outfile, header=True, index=False)

# %%
def select_quant_summary(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("""SELECT q.epa_srcid,q.station_id,g.lat,g.lon,q.analyte_name,q.abbreviation,
                   q.cas,q.conc_ppt,q.class,q.rl_ppt,q.source_file,q.trip_no,q.station_name,
                   q.sample_date,q.lab, g.src_type, g.src_name, g.well_i_rat, g.intk_loc, g.depth
                   FROM quant_summary q 
                   INNER JOIN geolocation g ON g.EPA_srcID = q.EPA_srcID
                   ORDER BY q.epa_srcid""")

    rows = cur.fetchall()
    
    df = pd.DataFrame(columns = ['epa_srcid','station_id','lon','lat','analyte_name','abbreviation','cas',
                                 'conc_ppt','class','rl_ppt','source_file','trip_no','station_name',
                                 'sample_date','lab','src_type', 'src_name', 'well_i_rat', 'intk_loc', 'depth']) 
    for row in rows:
        df = df.append({'epa_srcid': row[0],'station_id': row[1],'lon': row[2],'lat': row[3],
                        'analyte_name': row[4],'abbreviation': row[5],'cas': row[6],'conc_ppt': row[7],
                        'class': row[8],'rl_ppt': row[9],'source_file': row[10],'trip_no': row[11],
                        'station_name': row[12],'sample_date': row[13],'lab': row[14],'src_type': row[15], 
                        'src_name': row[16], 'well_i_rat': row[17], 'intk_loc': row[18], 'depth': row[19]}, 
                  ignore_index = True)

    return df

# %%
df = select_quant_summary(conn)
df.head()
# Out:
#   epa_srcid station_id        lon        lat  \
# 0     11606  NC0103010 -81.134111  36.512317
# 1     11606  NC0103010 -81.134111  36.512317
# 2     11606  NC0103010 -81.134111  36.512317
# 3     11606  NC0103010 -81.134111  36.512317
# 4     11606  NC0103010 -81.134111  36.512317
#
#                                         analyte_name abbreviation  \
# 0                   Perfluoro-2-ethoxypropanoic acid         PEPA
# 1  1,1,2,2-tetrafluoro-2-(1,2,2,2-tetrafluoro-eth...        NVHOS
# 2  N-(3-dimethylaminopropan-1-yl)perfluoro-1-hexa...   N-AP-FHxSA
# 3                       Perfluorononanesulfonic acid         PFNS
# 4                             Perfluorooctanoic acid         PFOA
#
#            cas conc_ppt                                   class rl_ppt  \
# 0  267239-61-2     None       Perfluoroalkylether Acids (PFEAs)      1
# 1          N/A     None       Perfluoroalkylether Acids (PFEAs)      5
# 2   50598-28-2     None                             Zwitterions     10
# 3   68259-12-1     None    Perfluoroalkylsulfonic Acids (PFSAs)      2
# 4     335-67-1     None  Perfluoroalkylcarboxylic acids (PFCAs)      2
#
#                                          source_file trip_no     station_name  \
# 0  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17  SPARTA, TOWN OF
# 1  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17  SPARTA, TOWN OF
# 2  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17  SPARTA, TOWN OF
# 3  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17  SPARTA, TOWN OF
# 4  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17  SPARTA, TOWN OF
#
#   sample_date     lab src_type src_name well_i_rat intk_loc depth
# 0  2019-07-02  Knappe        G  WELL #9          H     None   329
# 1  2019-07-02  Knappe        G  WELL #9          H     None   329
# 2  2019-07-02  Knappe        G  WELL #9          H     None   329
# 3  2019-07-02  Knappe        G  WELL #9          H     None   329
# 4  2019-07-02  Knappe        G  WELL #9          H     None   329

# %%
outfile = '../RoundOneDB/RoundOneDB-QuantSummary.csv'
df.to_csv(outfile, header=True, index=False)

# %%
def count_station_ids(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("""SELECT DISTINCT epa_srcid FROM quant_summary
                   ORDER BY epa_srcid""")

    rows = cur.fetchall()
    
    for row in rows:
        epa_srcid = row[0]
        cur.execute("""SELECT DISTINCT station_id, sample_date FROM quant_summary
                       WHERE epa_srcid = ? ORDER BY station_id""",
                   (epa_srcid,))
        
        srows = cur.fetchall()
        if len(srows) == 1:
            for srow in srows:
                print(epa_srcid,srow[0],srow[1])

# %%
count_station_ids(conn)
# Out:
# 11606 NC0103010 2019-07-02
# 11736 NC0105010 2019-07-02
# 11747 NC0105015-2 2019-07-02
# 11748 NC0105020 2019-10-09
# 11886 NC0106015 2019-07-03
# 11894 NC0106025 2019-07-03
# 12111 NC0111020 2019-06-24
# 12369 NC0111484 2019-07-30
# 14068 NC0122010 2019-07-26
# 15144 NC0138105 2019-07-25
# 17170 NC0156025 2019-06-24
# 17612 NC0158015-1 2019-07-10
# 17615 NC0158015-2 2019-10-09
# 17616 NC0158020 2019-07-11
# 18600 NC0161010 2019-10-09
# 18601 NC0161015 2019-10-09
# 18648 NC0175015 2019-08-12
# 18765 NC0180050 2019-06-03
# 19326 NC0181020 2019-06-24
# 19637 NC0187010 2019-07-25
# 19829 NC0188010 2019-08-12
# 20088 NC0190010 2019-08-24
# 20609 NC0195118 2019-07-03
# 20844 NC0197050 2019-04-17
# 21433 NC0217015 2019-06-11
# 22844 NC0276025 2019-07-17
# 23726 NC0285015 2019-07-18
# 23730 NC0285020 2019-07-11
# 24697 NC0299020 2019-04-16
# 24989 NC0309015 2019-08-29
# 24990 NC0309020 2019-10-16
# 24993 NC0309025 2019-08-29
# 24996 NC0309030 2019-08-29
# 25001 NC0309050 2019-05-29
# 25006 NC0309055 2019-08-29
# 39274 NC0343010 2019-04-10
# 39276 NC0343045 2019-04-09
# 39277 NC0351010 2019-04-10
# 39278 NC0351070 2019-04-10
# 39288 NC0353010 2019-04-09
# 39289 NC0353130 2019-04-09
# 39290 NC0362010 2019-07-30
# 39294 NC0363010 2019-08-24
# 39296 NC0363025-1 2019-07-30
# 39297 NC0363025-2 2019-07-30
# 39303 NC0368010 2019-05-02
# 39304 NC0368015 2019-05-02
# 39305 NC0368020 2019-05-02
# 39306 NC0377010 2019-08-23
# 39308 NC0377015 2019-08-24
# 39309 NC0377109 2019-08-23
# 39310 NC0378010-2 2019-08-30
# 39312 NC0392010 2019-04-10
# 39313 NC0392010-1 2019-04-10
# 39317 NC0392020 2019-04-09
# 39320 NC0392992-2 2019-04-22
# 39321 NC0392992-1 2019-04-22
# 39322 NC0410045-1 2019-05-29
# 39323 NC0424820 2019-06-29
# 39325 NC0433010 2019-06-25
# 39326 NC0442010-2 2019-09-17
# 39327 NC0442010-1 2019-09-17
# 39328 NC0442020 2019-09-17
# 39329 NC0442025 2019-06-25
# 39330 NC0464010 2019-06-25
# 39333 NC0465010-1 2019-05-29
# 39334 NC0465010 2019-07-16
# 39338 NC0496010 2019-08-20
# 39343 NC0498010-2 2019-08-06
# 39344 NC0498010-1 2019-08-06
# 65263 NC0286020-2 2019-04-17
# 65281 NC0407025 2019-04-24
# 66223 NC0472025 2019-08-20
# 66799 NC0180055 2019-06-03
# 67146 NC0446010 2019-08-20
# 68214 NC0149010-1 2019-04-16
# 69783 NC0230015-3 2019-07-11
# 70125 NC0113025 2019-08-12
# 70211 NC6054001 2019-08-06
# 70482 NC0347010 2019-08-22
# 71288 NC0465232 2019-07-16
# 71348 NC0410130 2019-05-29
# 71661 NC0425010 2019-08-06
# 71958 NC7024013 2019-11-05
# 71962 NC0431025 2019-07-16
# 71963 NC6059015-1 2019-08-06
# 71995 NC3076010 2019-08-24
# 72318 NC0106010 2019-07-03
# 72434 NC0106020 2019-07-03
# 72708 NC0448020 2019-08-20
# 72833 NC0467010 2019-05-07
# 72946 NC0378030 2019-08-22
# 72995 NC0138010-4 2019-07-25
# 73099 NC1081024 2019-07-10
# 73132 NC5009012 2019-08-22
# 73153 NC0496065-3 2019-08-20
# 73167 NC0465137 2019-07-16
# 73220 NC6070000 2019-08-20
# 73511 NC7071011 2019-05-29
# 73689 NC7071054 2019-05-29
# 73728 NC0498035 2019-08-06
# 73906 NC0383010 2019-08-22
# 74403 NC0382070 2019-10-16
# 74543 NC0347025 2019-08-22
# 74651 NC0446030 2019-09-18
# 74765 NC0408010 2019-08-06
# 74912 NC6059015 2019-08-06
# 75408 NC4032018 2019-07-11
# 75498 NC0309010 2019-08-29

# %%
def getStations(conn):
    cur = conn.cursor()
    cur.execute("""select distinct q.station_id, q.station_name, q.epa_srcid, q.sample_date, g.lon, g.lat 
                   from quant_summary q INNER JOIN geolocation g ON g.EPA_srcID = q.EPA_srcID 
                   order by station_id""")
    rows = cur.fetchall()
    
    df = pd.DataFrame(columns = ['station_id', 'station_name', 'epa_srcid', 'sample_date', 'lon', 'lat']) 
    for row in rows:
        df = df.append({'station_id': row[0], 'station_name': row[1], 'epa_srcid': row[2], 
                        'sample_date': row[3], 'lon': row[4], 'lat': row[5]}, 
                  ignore_index = True)

    return df

# %%
db_file = '../RoundOneDB/RoundOneDB_final.db'
conn = create_connection(db_file)
df = getStations(conn)
df.head()
# Out:
#     station_id             station_name epa_srcid sample_date        lon  \
# 0  NC0100010-1      BURNSVILLE, TOWN OF     39013  2019-07-31  35.900561
# 1  NC0100010-2      BURNSVILLE, TOWN OF     39012  2019-10-09  35.872044
# 2    NC0103010          SPARTA, TOWN OF     11606  2019-07-02  36.512317
# 3    NC0105010  WEST JEFFERSON, TOWN OF     11736  2019-07-02  36.408568
# 4  NC0105015-1   JEFFERSON, TOWN OF - 1     39024  2019-07-02  36.411667
#
#          lat
# 0 -82.315046
# 1 -82.280285
# 2 -81.134111
# 3 -81.496376
# 4 -81.404243

# %%
a = list(df['epa_srcid'])
list(valfilter(lambda count: count > 1, frequencies(a)).keys())
# Out:
# [39113, 39114, 39256, 39336]

# %%
df = pd.read_csv('../RoundOneDB/stationNames.csv', sep='|')
df.head()
# Out:
#    epa_srcid   station_id             station_name                  src_name  \
# 0      39013  NC0100010-1      BURNSVILLE, TOWN OF                CANE RIVER
# 1      39012  NC0100010-2      BURNSVILLE, TOWN OF              BOLENS CREEK
# 2      11606    NC0103010          SPARTA, TOWN OF                   WELL #9
# 3      11736    NC0105010  WEST JEFFERSON, TOWN OF  WELL #3A-WEST SEVENTH ST
# 4      39024  NC0105015-1   JEFFERSON, TOWN OF - 1         SO FORK NEW RIVER
#
#                       src_locati src_type src_avl  depth        lat        lon
# 0       2 MILES UP CANE RIVER RD        S       P    NaN -82.315046  35.900561
# 1        HWY 19 TO 197N  SR 1198        S       P    NaN -82.280285  35.872044
# 2           MITCHELL MOUNTAIN RD        G       P  329.0 -81.134111  36.512317
# 3   WEST 7TH ST OUTSIDE OF FENCE        G       P  500.0 -81.496376  36.408568
# 4  DON WALTERS RD PAST JEFFERSON        S       P    NaN -81.404243  36.411667

# %%
src = list(df['src_type'])
src
# Out:
# ['S',
#  'S',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'G',
#  'G',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'G',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G',
#  'S',
#  'G',
#  'G',
#  'S',
#  'G',
#  'S',
#  'G',
#  'G',
#  'G',
#  'G',
#  'G',
#  'S',
#  'G']

# %%
depth = list(df['depth'])
np.nanmax(depth)
# Out:
# 1000.0

# %%
np.nanmin(depth)
# Out:
# 40.0

# %%
def select_quant_summary2(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("""SELECT q.epa_srcid,q.station_id,g.lat,g.lon,q.analyte_name,q.abbreviation,
                   q.cas,q.conc_ppt,q.class,q.rl_ppt,q.source_file,q.trip_no,q.station_name,
                   q.sample_date,q.lab, g.src_type, g.src_name, g.well_i_rat, g.intk_loc, g.depth
                   FROM quant_summary q 
                   INNER JOIN geolocation g ON g.EPA_srcID = q.EPA_srcID
                   WHERE q.conc_ppt NOT NULL
                   ORDER BY q.epa_srcid""")

    rows = cur.fetchall()
    
    df = pd.DataFrame(columns = ['epa_srcid','station_id','lon','lat','analyte_name','abbreviation','cas',
                                 'conc_ppt','class','rl_ppt','source_file','trip_no','station_name',
                                 'sample_date','lab','src_type', 'src_name', 'well_i_rat', 'intk_loc', 'depth']) 
    for row in rows:
        df = df.append({'epa_srcid': row[0],'station_id': row[1],'lon': row[2],'lat': row[3],
                        'analyte_name': row[4],'abbreviation': row[5],'cas': row[6],'conc_ppt': row[7],
                        'class': row[8],'rl_ppt': row[9],'source_file': row[10],'trip_no': row[11],
                        'station_name': row[12],'sample_date': row[13],'lab': row[14],'src_type': row[15], 
                        'src_name': row[16], 'well_i_rat': row[17], 'intk_loc': row[18], 'depth': row[19]}, 
                  ignore_index = True)

    return df

# %%
db_file = '../RoundOneDB/RoundOneDB_final.db'
conn = create_connection(db_file)
df = select_quant_summary2(conn)
df.head()
# Out:
#   epa_srcid station_id        lon        lat                  analyte_name  \
# 0     11736  NC0105010 -81.496376  36.408568  Perfluorobutanesulfonic acid
# 1     11736  NC0105010 -81.496376  36.408568  Perfluorohexanesulfonic acid
# 2     12111  NC0111020 -82.334676  35.628290        Perfluorooctanoic acid
# 3     12111  NC0111020 -82.334676  35.628290      Perfluoroundecanoic acid
# 4     17170  NC0156025 -82.157259  35.641169        Perfluorooctanoic acid
#
#   abbreviation        cas  conc_ppt                                   class  \
# 0         PFBS   375-73-5     3.399    Perfluoroalkylsulfonic Acids (PFSAs)
# 1        PFHxS   355-46-4     4.438    Perfluoroalkylsulfonic Acids (PFSAs)
# 2         PFOA   335-67-1     2.200  Perfluoroalkylcarboxylic acids (PFCAs)
# 3       PFUnDA  2058-94-8     1.300  Perfluoroalkylcarboxylic acids (PFCAs)
# 4         PFOA   335-67-1     1.800  Perfluoroalkylcarboxylic acids (PFCAs)
#
#    rl_ppt                                        source_file trip_no  \
# 0     1.0  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17
# 1     2.0  E:/TraceFinderData/Projects/PFAST/Reports/Trip...      17
# 2     1.0           C:/Users/asj31/Desktop/PFaster/Trip24.db      24
# 3     1.0           C:/Users/asj31/Desktop/PFaster/Trip24.db      24
# 4     1.0           C:/Users/asj31/Desktop/PFaster/Trip24.db      24
#
#               station_name sample_date       lab src_type  \
# 0  WEST JEFFERSON, TOWN OF  2019-07-02    Knappe        G
# 1  WEST JEFFERSON, TOWN OF  2019-07-02    Knappe        G
# 2  BLACK MOUNTAIN, TOWN OF  2019-06-24  Ferguson        G
# 3  BLACK MOUNTAIN, TOWN OF  2019-06-24  Ferguson        G
# 4        OLD FORT, TOWN OF  2019-06-24  Ferguson        G
#
#                    src_name well_i_rat intk_loc depth
# 0  WELL #3A-WEST SEVENTH ST          H     None   500
# 1  WELL #3A-WEST SEVENTH ST          H     None   500
# 2                   WELL #1          M     None   505
# 3                   WELL #1          M     None   505
# 4                  WELL #10          M     None   305

# %%
outfile = '../RoundOneDB/RoundOneDB-QuantSummary-NN.csv'
df.to_csv(outfile, header=True, index=False)

# %%
np.unique(np.array(df['src_type']))
# Out:
# array(['G', 'S'], dtype=object)
